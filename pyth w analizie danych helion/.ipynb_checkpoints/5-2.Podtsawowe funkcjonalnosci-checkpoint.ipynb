# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# # 5. Rozpoczynamy pracę z biblioteką pandas..............................................................129
# ## 5.1. Wprowadzenie do struktur danych biblioteki pandas 130
# ### Obiekt Series 130
# ### Obiekt DataFrame 134
# ### Obiekty index 141
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5.2. Podstawowe funkcjonalności 142

# %%
obj = pd.Series([4.5,7.2,-5.3,3.6],index=['d','b','a','c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %% [markdown]
# ### Uaktualnianie indeksu 143
#
# changing the data order and adopting to the new index (zmiana kolejnosci danych  i przystosowanie do nowego indeksu)

# %%
obj2 = obj.reindex(['a','b','c','d','e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue','purple','yellow'],index=[0,2,4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
# przy szeregach czasowych - moze bedzie trzeba uzyc opcji z metody *ffill*; wypelnia wartości do przodu

obj3.reindex(range(6),method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
# w przypadku DataFrame - zmiana kolejnosci wierszy indeksu, kolumn lub obu tych elementow
# np.arange - z biblioteki numpy wykorzystanie; wypelnia od 1 do 9 w 3 kolumny i 3 wiersze
frame = pd.DataFrame(np.arange(9).reshape((3,3)),
                      index = ['a','b','c'],
                      columns = ['Ohio','Texas','California']
                      )
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# b     3      4           5
# c     6      7           8

# %%
frame_t = pd.DataFrame(np.arange(16).reshape((4,4)),
                      index = ['a','b','c','d'],
                      columns = ['Ohio','Texas','California','aaa']
                      )
frame_t
# Out:
#    Ohio  Texas  California  aaa
# a     0      1           2    3
# b     4      5           6    7
# c     8      9          10   11
# d    12     13          14   15

# %%
frame2 = frame.reindex(['a','d','b','c'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# d   NaN    NaN         NaN
# b   3.0    4.0         5.0
# c   6.0    7.0         8.0

# %%
# uaktualnienie kolumn
states = ['Texas','Utah','California']
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# b      4   NaN           5
# c      7   NaN           8

# %%
# Another way to update the index, add new labels in the position argument and next point this axe with the use of the axis keyword 
frame.reindex(states, axis="columns")
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# b      4   NaN           5
# c      7   NaN           8

# %%
# in case of reindex method - it inserts NaN values when adding new indexes

# %% [markdown]
# ### rejecting axes elements
#
# - two methods possible: reindex or loc; method drop - returns a new object
# np.arange
# NumPy arange() is one of the array creation routines based on numerical ranges. It creates an instance of ndarray with evenly spaced values and returns the reference to it
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
obj = pd.Series(np.arange(5.),index=(['a','b','c','d','e']))
#obj2 = pd.Series(np.arange(1,10,2),index=(['a','b','c','d','e']))
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
dropObjC = obj.drop('c')
dropObjC
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop(['d','c'])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
# we can remove any data i dataframe. additional example
# creating dataframe with np.arange ang reshape, adding index and column names
data = pd.DataFrame(np.arange(16).reshape(4,4),
        index = ['Ohio','Colorado','Utha','New York'],
        columns = ['one','two','three','four']
)
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utha        8    9     10    11
# New York   12   13     14    15

# %%
# drop with labels 
data.drop(['Ohio','Colorado'])
# Out:
#           one  two  three  four
# Utha        8    9     10    11
# New York   12   13     14    15

# %%
# drop columns
data.drop(columns=['two'])
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utha        8     10    11
# New York   12     14    15

# %%
# drop doesn't modify the object 
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utha        8    9     10    11
# New York   12   13     14    15

# %%
# other way 
data.drop('two',axis=1) # removing column
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utha        8     10    11
# New York   12     14    15

# %%
data.drop(['two','four'], axis='columns')
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utha        8     10
# New York   12     14

# %% [markdown]
# ### index, select and filter

# %%
obj = pd.Series(np.arange(4.),index = ['a','b','c','d'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['b']
# Out:
# 1.0

# %%
obj[1]
# Out:
# 1.0

# %%
obj[2:4]
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
 obj[['a','d','b']] # an error with multiindex, without two square brackets
# Out:
# a    0.0
# d    3.0
# b    1.0
# dtype: float64

# %%
obj[[1,3]]
# Out:
# b    1.0
# d    3.0
# dtype: float64

# %%
obj[obj<=2]
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
obj[obj<2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
# this way you can select data by labels, but there is a better way - use loc

# %%
obj.loc[['b','a','d']]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
# why loc - it treats integers differently when indexing with square brackets

# %%
obj1 = pd.Series([1,2,3],index=[2,0,1])
obj1
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj2 = pd.Series([1,2,3],index=['a','b','c'])
obj2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj1[[0,1,2]]
# Out:
# 0    2
# 1    3
# 2    1
# dtype: int64

# %%
obj2[[0,1,2]]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# if an index doesn't contain integers, then using the expression obj.loc[[0,1,2]] ends a failure

# %%
#obj.loc[[0,1,2]]

# %%
# 20230709
# Except for loc operator, iloc indexes only with integers. Thanks to that, it works correctly regardless an index contains integers or not.

# %%
obj1.iloc[[0,1,2]]
# Out:
# 2    1
# 0    2
# 1    3
# dtype: int64

# %%
obj2.iloc[[0,1,2]]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj2.loc['b':'c']
# Out:
# b    2
# c    3
# dtype: int64

# %%
obj2.loc['b':'c'] = 5
obj2
# Out:
# a    1
# b    5
# c    5
# dtype: int64

# %%
# DataFrame index lets gain access to the chosen column or selected columns
data = pd.DataFrame(np.arange(16).reshape((4,4)),
                    index = ['Ohio','Colorado','Utah','New York'],
                    columns = ['one','two','three','four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data[['three','one']]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
data[:2] # chosing rows     - without square brackets
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data[data['three']>5] # one element or square brackets []  means selecting columns
# select data where in column three we data higher than 5
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# scalar comparing

# %%
data < 5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# New York  False  False  False  False

# %%
# using this method we can assign data
data[data < 5] = 0 
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# #### wybieranie za pomocą operatorów loc i iloc
# These operators help to select a subset of data rows and columns from dataframe (a notion similar to NumPy)
# thanks to
# - loc - axis labels # lokalizacja po lablels - <b>loc</b>
# - iloc - integer values   - int loc -> - <b>iloc</b>
#
# ![image-7.png](attachment:image-7.png)
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc["Colorado"] # selecting one row using label, vertical view - seria for one row
# or data.iloc[2]
# Out:
# one      0
# two      5
# three    6
# four     7
# Name: Colorado, dtype: int32

# %%
data.loc[["Colorado","New York"]] # normal view for more than 1 element 
# or data.iloc[[1,3]]
# Out:
#           one  two  three  four
# Colorado    0    5      6     7
# New York   12   13     14    15

# %%
# you can join selecting rows, separating labels by comma  
# subset of data
data.loc[["Colorado","New York"],["two","three"]]
# or data.iloc[[1,3],[2,1]]
# Out:
#           two  three
# Colorado    5      6
# New York   13     14

# %%
# now I use the same operations using iloc
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int32

# %%
data.iloc[[1,3]]
# Out:
#           one  two  three  four
# Colorado    0    5      6     7
# New York   12   13     14    15

# %%
data.iloc[[2,1]]
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# Colorado    0    5      6     7

# %%
data.iloc[2,[3,0,1]]  # second row, columns 3=four, 0=one, 1=two
# Out:
# four    11
# one      8
# two      9
# Name: Utah, dtype: int32

# %%
data.iloc[[1,3],[2,1]]
# Out:
#           three  two
# Colorado      6    5
# New York     14   13

# %%
# both functions work with slices (wycinkaimi ":2")
data.loc[:'Utah','two']
# Out:
# Ohio        0
# Colorado    5
# Utah        9
# Name: two, dtype: int32

# %%
data.iloc[:,:3][data.three>5]
# Out:
#           one  two  three
# Colorado    0    5      6
# Utah        8    9     10
# New York   12   13     14

# %% [markdown]
# slice notation
# ![image.png](attachment:image.png)

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# 20230710
# Logic tables can be used wit loc operator, not with iloc

data.loc[data.three >= 7] # dsp rows where data >= 7 in three column
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# Indexing option of DataFrame - table
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pitfalls of integer indexing - Pułapki indeksowania całkowitoliczbiwego
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
# 20230712 
# jest roznica dkładni indeksowania pomiędzy strukturami pandas a wbudowanymi strukturami Pythona - listami i krotkami

ser = pd.Series(np.arange(3.))
ser
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64

# %%
# ser[-1] -> bład, pandas nie wie jakie indeksowanie chce user; czy etykieta czy numer pozycji



# dla indexow innych niz integer, jest ok

ser2 = pd.Series(np.arange(3.),index=['a','b','c'])
ser2
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
ser2[-1]
# Out:
# 2.0

# %%
# lepiej skorzystać z 
ser.iloc[-1]
# Out:
# 2.0

# %%
# wycinanie zawsze na liczby calkowite 

ser[:2]
# Out:
# 0    0.0
# 1    1.0
# dtype: float64

# %%
# aby uniknąć niejednoznaczności, stosuj zawsze loc  iloc
# to avoid ambiguity, always applay loc iloc methods

# %% [markdown]
# ####  pułapki łączonego indexowania - pitfalls of combined indexing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.iloc[1:4,1:2]
# Out:
#           two
# Colorado    5
# Utah        9
# New York   13

# %%
# thanks to loc, we can not only select data, but we can change them

data.loc[:,"one"]=1
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    1    5      6     7
# Utah        1    9     10    11
# New York    1   13     14    15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.iloc[2] = 5
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    1    5      6     7
# Utah        5    5      5     5
# New York    1   13     14    15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data.loc[data['four']>5] = 3
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    3    3      3     3
# Utah        5    5      5     5
# New York    3    3      3     3

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
data
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    3    3      3     3
# Utah        5    5      5     5
# New York    3    3      3     3

# %%
data.loc[data['four']>=0]  # wybierz wszystkie wiersze gdzie wartosc >=0 dla kolumny 'four'
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    3    3      3     3
# Utah        5    5      5     5
# New York    3    3      3     3

# %%
data.loc[data['four']>=3] # wybierz wszystkie wiersze gdzie wartosc >=3 dla kolumny 'four'
# Out:
#           one  two  three  four
# Colorado    3    3      3     3
# Utah        5    5      5     5
# New York    3    3      3     3

# %%
data.loc[data['four']==5] = -1  # przypisz -1
data                            # wyswietl po zmianie
# Out:
#           one  two  three  four
# Ohio        1    0      0     0
# Colorado    3    3      3     3
# Utah       -1   -1     -1    -1
# New York    3    3      3     3

# %%
data.loc[data['four']>=3] # wybierz
# Out:
#           one  two  three  four
# Colorado    3    3      3     3
# New York    3    3      3     3

# %% [markdown]
# ### Działania arytmetyczne i wyrównywanie danych 156

# %%
# If indexes are not the same while adding data, they will be presented in the union.

s1 = pd.Series([7.3,-2.5,3.4,1.5],index=['a','c','d','e'])
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2 = pd.Series([-2.1,3.6,-1.5,4,3.1],index=['a','c','e','f','g'])
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3,3)),columns=list('bcd'),
                   index=['Ohio','Texas','Colorado'])
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2= pd.DataFrame(np.arange(12.).reshape((4,3)),columns=list('bde'),
                   index=['Utah','Ohio','Texas','Colorado'])
df2
# Out:
#             b     d     e
# Utah      0.0   1.0   2.0
# Ohio      3.0   4.0   5.0
# Texas     6.0   7.0   8.0
# Colorado  9.0  10.0  11.0

# %%
df1+df2
# Out:
#              b   c     d   e
# Colorado  15.0 NaN  18.0 NaN
# Ohio       3.0 NaN   6.0 NaN
# Texas      9.0 NaN  12.0 NaN
# Utah       NaN NaN   NaN NaN

# %%
df1 = pd.DataFrame({'A':[1,2]})
df2 = pd.DataFrame({'B':[3,4]})

# %%
df1+df2
# Out:
#     A   B
# 0 NaN NaN
# 1 NaN NaN

# %% [markdown]
# #### metody arytmetyczne i wypelnianie wartosiami

# %% [markdown]
# ### Funkcje apply i map 161
# ### Sortowanie i tworzenie rankingów 163
# ### Indeksy osi ze zduplikowanymi etykietami 167
# ## 5.3. Podsumowywanie i generowanie statystyk opisowych 168
# ### Współczynnik korelacji i kowariancja 171
# ### Unikalne wartości, ich liczba i przynależność 173
# ##  5.4. Podsumowanie 176
